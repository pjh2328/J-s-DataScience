# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
arabica = pd.read_csv("../data/archive/arabica_data_cleaned.csv")
robusta = pd.read_csv("../data/archive/robusta_data_cleaned.csv")
merged = pd.read_csv("../data/archive/merged_data_cleaned.csv")

# %%
merged_data = merged[["Species",'Aroma','Flavor','Acidity','Body','Balance','Uniformity','Sweetness',
                     'Total.Cup.Points','Moisture']]
merged_data
# Out:
#       Species  Aroma  Flavor  Acidity  Body  Balance  Uniformity  Sweetness  \
# 0     Arabica   8.67    8.83     8.75  8.50     8.42       10.00      10.00
# 1     Arabica   8.75    8.67     8.58  8.42     8.42       10.00      10.00
# 2     Arabica   8.42    8.50     8.42  8.33     8.42       10.00      10.00
# 3     Arabica   8.17    8.58     8.42  8.50     8.25       10.00      10.00
# 4     Arabica   8.25    8.50     8.50  8.42     8.33       10.00      10.00
# ...       ...    ...     ...      ...   ...      ...         ...        ...
# 1334  Robusta   7.75    7.58     7.58  5.08     7.83       10.00       7.75
# 1335  Robusta   7.50    7.67     7.75  5.17     5.25       10.00       8.42
# 1336  Robusta   7.33    7.33     7.42  7.50     7.17        9.33       7.42
# 1337  Robusta   7.42    6.83     7.17  7.25     7.00        9.33       7.08
# 1338  Robusta   6.75    6.67     6.83  6.92     6.83        9.33       6.67
#
#       Total.Cup.Points  Moisture
# 0                90.58      0.12
# 1                89.92      0.12
# 2                89.75      0.00
# 3                89.00      0.11
# 4                88.83      0.12
# ...                ...       ...
# 1334             78.75      0.00
# 1335             78.08      0.00
# 1336             77.17      0.00
# 1337             75.08      0.10
# 1338             73.75      0.12
#
# [1339 rows x 10 columns]

# %%
merged_data.describe()
# Out:
#              Aroma       Flavor      Acidity         Body      Balance  \
# count  1339.000000  1339.000000  1339.000000  1339.000000  1339.000000
# mean      7.566706     7.520426     7.535706     7.517498     7.518013
# std       0.377560     0.398442     0.379827     0.370064     0.408943
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       7.420000     7.330000     7.330000     7.330000     7.330000
# 50%       7.580000     7.580000     7.580000     7.500000     7.500000
# 75%       7.750000     7.750000     7.750000     7.670000     7.750000
# max       8.750000     8.830000     8.750000     8.580000     8.750000
#
#         Uniformity    Sweetness  Total.Cup.Points     Moisture
# count  1339.000000  1339.000000       1339.000000  1339.000000
# mean      9.834877     9.856692         82.089851     0.088379
# std       0.554591     0.616102          3.500575     0.048287
# min       0.000000     0.000000          0.000000     0.000000
# 25%      10.000000    10.000000         81.080000     0.090000
# 50%      10.000000    10.000000         82.500000     0.110000
# 75%      10.000000    10.000000         83.670000     0.120000
# max      10.000000    10.000000         90.580000     0.280000

# %%
merged_data[['Total.Cup.Points']:['point']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 merged_data[['Total.Cup.Points']:['point']]
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3477, in DataFrame.__getitem__(self, key)
#    3474         return self._get_item_cache(key)
#    3476 # Do we have a slicer (on rows)?
# -> 3477 indexer = convert_to_index_sliceable(self, key)
#    3478 if indexer is not None:
#    3479     if isinstance(indexer, np.ndarray):
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:2324, in convert_to_index_sliceable(obj, key)
#    2322 idx = obj.index
#    2323 if isinstance(key, slice):
# -> 2324     return idx._convert_slice_indexer(key, kind="getitem")
#    2326 elif isinstance(key, str):
#    2327
#    2328     # we are an actual column
#    2329     if key in obj.columns:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\numeric.py:279, in NumericIndex._convert_slice_indexer(self, key, kind)
#     275     # We always treat __getitem__ slicing as label-based
#     276     # translate to locations
#     277     return self.slice_indexer(key.start, key.stop, key.step)
# --> 279 return super()._convert_slice_indexer(key, kind=kind)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:4041, in Index._convert_slice_indexer(self, key, kind)
#    4036 """
#    4037 called from the getitem slicers, validate that we are in fact
#    4038 integers
#    4039 """
#    4040 if self.is_integer() or is_index_slice:
# -> 4041     self._validate_indexer("slice", key.start, "getitem")
#    4042     self._validate_indexer("slice", key.stop, "getitem")
#    4043     self._validate_indexer("slice", key.step, "getitem")
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6308, in Index._validate_indexer(self, form, key, kind)
#    6305 assert kind in ["getitem", "iloc"]
#    6307 if key is not None and not is_integer(key):
# -> 6308     raise self._invalid_indexer(form, key)
#
# TypeError: cannot do slice indexing on RangeIndex with these indexers [['Total.Cup.Points']] of type list

# %%
sns.pairplot(merged_data, hue = 'Species')

# %%
# Out:
#       Species  Aroma  Flavor  Acidity  Body  Balance  Uniformity  Sweetness  \
# 0     Arabica   8.67    8.83     8.75  8.50     8.42       10.00      10.00
# 1     Arabica   8.75    8.67     8.58  8.42     8.42       10.00      10.00
# 2     Arabica   8.42    8.50     8.42  8.33     8.42       10.00      10.00
# 3     Arabica   8.17    8.58     8.42  8.50     8.25       10.00      10.00
# 4     Arabica   8.25    8.50     8.50  8.42     8.33       10.00      10.00
# ...       ...    ...     ...      ...   ...      ...         ...        ...
# 1334  Robusta   7.75    7.58     7.58  5.08     7.83       10.00       7.75
# 1335  Robusta   7.50    7.67     7.75  5.17     5.25       10.00       8.42
# 1336  Robusta   7.33    7.33     7.42  7.50     7.17        9.33       7.42
# 1337  Robusta   7.42    6.83     7.17  7.25     7.00        9.33       7.08
# 1338  Robusta   6.75    6.67     6.83  6.92     6.83        9.33       6.67
#
#       Total.Cup.Points  Moisture
# 0                90.58      0.12
# 1                89.92      0.12
# 2                89.75      0.00
# 3                89.00      0.11
# 4                88.83      0.12
# ...                ...       ...
# 1334             78.75      0.00
# 1335             78.08      0.00
# 1336             77.17      0.00
# 1337             75.08      0.10
# 1338             73.75      0.12
#
# [1339 rows x 10 columns]
