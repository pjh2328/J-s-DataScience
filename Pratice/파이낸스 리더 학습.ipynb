# %%
# !pip install finance-datareader

# %%
import FinanceDataReader as fdr
df_krx = fdr.StockListing("KRX")
df_krx.head()
# Out:
#    Symbol  Market    Name           Sector             Industry ListingDate  \
# 0  060310  KOSDAQ      3S         전자부품 제조업          반도체 웨이퍼 캐리어  2002-04-23
# 1  095570   KOSPI  AJ네트웍스  산업용 기계 및 장비 임대업  렌탈(파렛트, OA장비, 건설장비)  2015-08-21
# 2  006840   KOSPI   AK홀딩스           기타 금융업                 지주사업  1999-08-11
# 3  054620  KOSDAQ  APS홀딩스           기타 금융업          인터넷 트래픽 솔루션  2001-12-04
# 4  265520  KOSDAQ   AP시스템    특수 목적용 기계 제조업          디스플레이 제조 장비  2017-04-07
#
#   SettleMonth     Representative                       HomePage Region
# 0         03월                김세완           http://www.3sref.com  서울특별시
# 1         12월           박대현, 손삼달         http://www.ajnet.co.kr  서울특별시
# 2         12월  채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr  서울특별시
# 3         12월                정기로   http://www.apsholdings.co.kr    경기도
# 4         12월                김영주     http://www.apsystems.co.kr    경기도

# %%
import FinanceDataReader as fdr
df_spx = fdr.StockListing("S&P500")
df_spx.head()
# Out:
# C:\Users\pjh23\anaconda3\lib\site-packages\FinanceDataReader\wikipedia\listing.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Symbol'] = df['Symbol'].str.replace('\.', '')
#   Symbol         Name       Sector                  Industry
# 0    MMM           3M  Industrials  Industrial Conglomerates
# 1    AOS  A. O. Smith  Industrials         Building Products
# 2    ABT       Abbott  Health Care     Health Care Equipment
# 3   ABBV       AbbVie  Health Care           Pharmaceuticals
# 4   ABMD      Abiomed  Health Care     Health Care Equipment

# %%
df = fdr.DataReader(symbol='005930', start='2020')
df
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2020-01-02  55500  56000  55000  55200  12993228 -0.010753
# 2020-01-03  56000  56600  54900  55500  15422255  0.005435
# 2020-01-06  54900  55600  54600  55500  10278951  0.000000
# 2020-01-07  55700  56400  55600  55800  10009778  0.005405
# 2020-01-08  56200  57400  55900  56800  23501171  0.017921
# ...           ...    ...    ...    ...       ...       ...
# 2022-08-29  58700  58900  58600  58600   9841329 -0.023333
# 2022-08-30  58700  59000  58300  58800   9690044  0.003413
# 2022-08-31  58200  59900  58200  59700  14203512  0.015306
# 2022-09-01  58700  58900  58300  58400  14905777 -0.021776
# 2022-09-02  58300  58600  57500  57700  12540522 -0.011986
#
# [662 rows x 6 columns]

# %%
import FinanceDataReader as fdr
df = fdr.DataReader(symbol='005930',start='20200101',end='20201231')
df
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2020-01-02  55500  56000  55000  55200  12993228 -0.010753
# 2020-01-03  56000  56600  54900  55500  15422255  0.005435
# 2020-01-06  54900  55600  54600  55500  10278951  0.000000
# 2020-01-07  55700  56400  55600  55800  10009778  0.005405
# 2020-01-08  56200  57400  55900  56800  23501171  0.017921
# ...           ...    ...    ...    ...       ...       ...
# 2020-12-23  72400  74000  72300  73900  19411326  0.022130
# 2020-12-24  74100  78800  74000  77800  32502870  0.052774
# 2020-12-28  79000  80100  78200  78700  40085044  0.011568
# 2020-12-29  78800  78900  77300  78300  30339449 -0.005083
# 2020-12-30  77400  81300  77300  81000  29417421  0.034483
#
# [248 rows x 6 columns]

# %%
import FinanceDataReader as fdr
df = fdr.DataReader(symbol='005930')
df
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 1998-06-23    795    808    763    765    474325       NaN
# 1998-06-24    765    778    735    768    705985  0.003922
# 1998-06-25    744    775    735    775    281780  0.009115
# 1998-06-26    754    791    754    754    302831 -0.027097
# 1998-06-27    757    780    756    769    140840  0.019894
# ...           ...    ...    ...    ...       ...       ...
# 2022-08-29  58700  58900  58600  58600   9841329 -0.023333
# 2022-08-30  58700  59000  58300  58800   9690044  0.003413
# 2022-08-31  58200  59900  58200  59700  14203512  0.015306
# 2022-09-01  58700  58900  58300  58400  14905777 -0.021776
# 2022-09-02  58300  58600  57500  57600  12616280 -0.013699
#
# [6000 rows x 6 columns]

# %%
df["Close"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
import FinanceDataReader as fdr
df = fdr.DataReader(symbol='AAPL',start='2020')
df
# Out:
#              Close    Open    High     Low       Volume  Change
# Date
# 2020-01-02   75.09   74.06   75.15   73.80  135650000.0  0.0229
# 2020-01-03   74.36   74.29   75.14   74.12  146540000.0 -0.0097
# 2020-01-06   74.95   73.45   74.99   73.19  118580000.0  0.0079
# 2020-01-07   74.60   74.96   75.22   74.37  111510000.0 -0.0047
# 2020-01-08   75.80   74.29   76.11   74.29  132360000.0  0.0161
# ...            ...     ...     ...     ...          ...     ...
# 2022-08-26  163.62  170.57  171.05  163.56   78960000.0 -0.0377
# 2022-08-29  161.38  161.15  162.90  159.82   73310000.0 -0.0137
# 2022-08-30  158.91  162.13  162.56  157.72   74790000.0 -0.0153
# 2022-08-31  157.22  160.12  160.56  157.19   85290000.0 -0.0106
# 2022-09-01  157.96  156.54  158.36  154.70   73540000.0  0.0047
#
# [673 rows x 6 columns]

# %%
import FinanceDataReader as fdr
df = fdr.DataReader(symbol="AAPL")
df
# Out:
# C:\Users\pjh23\anaconda3\lib\site-packages\FinanceDataReader\data.py:47: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(more)
# C:\Users\pjh23\anaconda3\lib\site-packages\FinanceDataReader\data.py:47: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(more)
#              Close    Open    High     Low       Volume  Change
# Date
# 1980-12-12    0.13    0.13    0.13    0.13  469030000.0 -0.9988
# 1980-12-15    0.12    0.12    0.12    0.12  175880000.0 -0.0769
# 1980-12-16    0.11    0.11    0.11    0.11  105730000.0 -0.0833
# 1980-12-17    0.12    0.12    0.12    0.12   86440000.0  0.0909
# 1980-12-18    0.12    0.12    0.12    0.12   73450000.0  0.0000
# ...            ...     ...     ...     ...          ...     ...
# ...

# %%
df["Close"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>
